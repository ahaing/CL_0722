# %%
import csv
filename='112q1.csv'
with open(filename, encoding='utf-8', newline='') as file:
    content = csv.DictReader(file)
    content_list = list(content)
content_list
# Out:
# [{'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '2',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '4',
#   '幾廳': '2',
#   '幾衛': '3',
#   '有無隔間': '有',
#   '建物型態': '透天厝',
#   '房地總價': '33,300,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1111122',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽新段',
#   '土地移轉面積': '97',
#   '代表地號都市土地使用分區': '其他-第五種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '291.42',
#   '代表建號主要用途': '住商用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '4',
#   '代表建號建築完成日期': '940408',
#   '代表建號屋齡': '18',
#   '代表建號層次': '一層;二層;三層;四層;騎樓;見其它登記事項;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '大勇路110號',
#   '行政區': '鹽埕區',
#   '地段': '鹽新段',
#   '代表地號': '2360000',
#   '代表建號': '705000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '9',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '無',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '32,530,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111201',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽新段',
#   '土地移轉面積': '41.1',
#   '代表地號都市土地使用分區': '其他-第五種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '306.44',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '11',
#   '代表建號建築完成日期': '720407',
#   '代表建號屋齡': '40',
#   '代表建號層次': '一層;二層;騎樓;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '大仁路47號',
#   '行政區': '鹽埕區',
#   '地段': '鹽新段',
#   '代表地號': '920000',
#   '代表建號': '231000',
#   '特殊交易態樣說明': '0201.親友、員工、共有人或其他特殊關係間之交易'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '3',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '10',
#   '幾廳': '5',
#   '幾衛': '5',
#   '有無隔間': '有',
#   '建物型態': '透天厝',
#   '房地總價': '21,000,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1111109',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽國段',
#   '土地移轉面積': '86',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '334.38',
#   '代表建號主要用途': '住商用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '5',
#   '代表建號建築完成日期': '670202',
#   '代表建號屋齡': '45',
#   '代表建號層次': '一層;二層;三層;四層;五層;防空避難室;騎樓;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '新樂街172號',
#   '行政區': '鹽埕區',
#   '地段': '鹽國段',
#   '代表地號': '2980000',
#   '代表建號': '643000',
#   '特殊交易態樣說明': '0101.裝潢費0304.其他增建'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '2',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '5',
#   '幾廳': '2',
#   '幾衛': '5',
#   '有無隔間': '有',
#   '建物型態': '透天厝',
#   '房地總價': '15,650,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120108',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽國段',
#   '土地移轉面積': '80',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '296.03',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '加強磚造',
#   '代表建號總層數': '4',
#   '代表建號建築完成日期': '540820',
#   '代表建號屋齡': '57',
#   '代表建號層次': '一層;二層;三層;四層;騎樓;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '瀨南街162號',
#   '行政區': '鹽埕區',
#   '地段': '鹽國段',
#   '代表地號': '2420000',
#   '代表建號': '378000',
#   '特殊交易態樣說明': '0304.其他增建'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '土地',
#   '土地數量': '2',
#   '建物數量': '0',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '有',
#   '建物型態': '',
#   '房地總價': '15,000,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1111216',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '大東段',
#   '土地移轉面積': '93',
#   '代表地號都市土地使用分區': '其他-第三種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '無建物主要建材',
#   '代表建號總層數': '',
#   '代表建號建築完成日期': '',
#   '代表建號屋齡': '',
#   '代表建號層次': '',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '大東段 331-0 地號',
#   '行政區': '鹽埕區',
#   '地段': '大東段',
#   '代表地號': '3310000',
#   '代表建號': '',
#   '特殊交易態樣說明': '0201.親友、員工、共有人或其他特殊關係間之交易0401.未登記建物'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '2',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '無',
#   '建物型態': '透天厝',
#   '房地總價': '11,600,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1111110',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '興仁段',
#   '土地移轉面積': '95',
#   '代表地號都市土地使用分區': '其他-第五種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '222.22',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '加強磚造',
#   '代表建號總層數': '3',
#   '代表建號建築完成日期': '370805',
#   '代表建號屋齡': '74',
#   '代表建號層次': '一層;二層;三層;騎樓;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '新興街164號',
#   '行政區': '鹽埕區',
#   '地段': '興仁段',
#   '代表地號': '540000',
#   '代表建號': '393000',
#   '特殊交易態樣說明': '0302.頂樓加蓋0304.其他增建'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '9,800,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111217',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '興福段',
#   '土地移轉面積': '12.8',
#   '代表地號都市土地使用分區': '其他-第三種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '116.14',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '14',
#   '代表建號建築完成日期': '951205',
#   '代表建號屋齡': '16',
#   '代表建號層次': '十層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '七賢三路3號十樓之6',
#   '行政區': '鹽埕區',
#   '地段': '興福段',
#   '代表地號': '5620000',
#   '代表建號': '1041000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '9,800,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111224',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '興福段',
#   '土地移轉面積': '14.61',
#   '代表地號都市土地使用分區': '其他-第三種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '132.67',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '14',
#   '代表建號建築完成日期': '951205',
#   '代表建號屋齡': '16',
#   '代表建號層次': '二層;',
#   '車位總價格': '0',
#   '車位總持分面積': '16.53',
#   '代表地號或門牌': '七賢三路3號二樓之7',
#   '行政區': '鹽埕區',
#   '地段': '興福段',
#   '代表地號': '5620000',
#   '代表建號': '990000',
#   '特殊交易態樣說明': '0102.傢俱設備費'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '9,600,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111123',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '興福段',
#   '土地移轉面積': '13.22',
#   '代表地號都市土地使用分區': '其他-第三種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '136.01',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '960103',
#   '代表建號屋齡': '16',
#   '代表建號層次': '二層;',
#   '車位總價格': '0',
#   '車位總持分面積': '6.65',
#   '代表地號或門牌': '七賢三路1號二樓之5',
#   '行政區': '鹽埕區',
#   '地段': '興福段',
#   '代表地號': '5660000',
#   '代表建號': '1121000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '4',
#   '幾廳': '2',
#   '幾衛': '4',
#   '有無隔間': '無',
#   '建物型態': '透天厝',
#   '房地總價': '9,000,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120116',
#   '備註欄': '土地建物拆價：土地810萬，建物90萬',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '大東段',
#   '土地移轉面積': '61',
#   '代表地號都市土地使用分區': '其他-第三種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '134.91',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '加強磚造',
#   '代表建號總層數': '3',
#   '代表建號建築完成日期': '641104',
#   '代表建號屋齡': '47',
#   '代表建號層次': '一層;二層;三層;地下層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '大勇路21巷7號',
#   '行政區': '鹽埕區',
#   '地段': '大東段',
#   '代表地號': '4280000',
#   '代表建號': '134000',
#   '特殊交易態樣說明': '0302.頂樓加蓋0303.夾層'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '8,900,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120103',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '興福段',
#   '土地移轉面積': '12.47',
#   '代表地號都市土地使用分區': '其他-第三種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '128.65',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '960103',
#   '代表建號屋齡': '16',
#   '代表建號層次': '二層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '七賢三路1號二樓之10',
#   '行政區': '鹽埕區',
#   '地段': '興福段',
#   '代表地號': '5660000',
#   '代表建號': '1114000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '2',
#   '車位數量': '',
#   '幾房': '4',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '公寓(5樓含以下無電梯)',
#   '房地總價': '8,100,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1111128',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '府北段五小段',
#   '土地移轉面積': '30.42',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '167.73',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '5',
#   '代表建號建築完成日期': '701020',
#   '代表建號屋齡': '41',
#   '代表建號層次': '二層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '大有街25號2樓之2',
#   '行政區': '鹽埕區',
#   '地段': '府北段五小段',
#   '代表地號': '2420000',
#   '代表建號': '1015000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '2',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '4',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '華廈(10層含以下有電梯)',
#   '房地總價': '7,500,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120129',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '興橋段',
#   '土地移轉面積': '14.97',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '137.77',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '7',
#   '代表建號建築完成日期': '701228',
#   '代表建號屋齡': '41',
#   '代表建號層次': '七層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '大仁路237之4號7樓之5',
#   '行政區': '鹽埕區',
#   '地段': '興橋段',
#   '代表地號': '2310000',
#   '代表建號': '109000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '1',
#   '幾廳': '1',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '6,800,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120114',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽壽段',
#   '土地移轉面積': '9.11',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '113.38',
#   '代表建號主要用途': '住商用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '11',
#   '代表建號建築完成日期': '841118',
#   '代表建號屋齡': '27',
#   '代表建號層次': '一層;二層;騎樓;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '新興街303號',
#   '行政區': '鹽埕區',
#   '地段': '鹽壽段',
#   '代表地號': '2720000',
#   '代表建號': '1188000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '2',
#   '幾廳': '2',
#   '幾衛': '1',
#   '有無隔間': '無',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '6,600,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120208',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '興福段',
#   '土地移轉面積': '8.79',
#   '代表地號都市土地使用分區': '其他-第三種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '80.2',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '14',
#   '代表建號建築完成日期': '951205',
#   '代表建號屋齡': '16',
#   '代表建號層次': '三層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '七賢三路3號三樓之3',
#   '行政區': '鹽埕區',
#   '地段': '興福段',
#   '代表地號': '5620000',
#   '代表建號': '979000',
#   '特殊交易態樣說明': '0102.傢俱設備費'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '3',
#   '車位數量': '',
#   '幾房': '0',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '華廈(10層含以下有電梯)',
#   '房地總價': '6,500,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1110814',
#   '備註欄': '本案含富野路46號48號50之2號三戶打通',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '府北段五小段',
#   '土地移轉面積': '7.34',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '45.66',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '10',
#   '代表建號建築完成日期': '710531',
#   '代表建號屋齡': '40',
#   '代表建號層次': '一層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '富野路50之2號',
#   '行政區': '鹽埕區',
#   '地段': '府北段五小段',
#   '代表地號': '2460000',
#   '代表建號': '1611000',
#   '特殊交易態樣說明': '0303.夾層'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '透天厝',
#   '房地總價': '6,500,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1111130',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '大榮段',
#   '土地移轉面積': '81',
#   '代表地號都市土地使用分區': '其他-第四種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '113.22',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '2',
#   '代表建號建築完成日期': '681115',
#   '代表建號屋齡': '43',
#   '代表建號層次': '一層;二層;地下層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '光榮街37巷1號',
#   '行政區': '鹽埕區',
#   '地段': '大榮段',
#   '代表地號': '3170000',
#   '代表建號': '202000',
#   '特殊交易態樣說明': '0301.陽台外推0302.頂樓加蓋0303.夾層'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '4',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '無',
#   '建物型態': '華廈(10層含以下有電梯)',
#   '房地總價': '6,500,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120118',
#   '備註欄': '頂樓增建(砌牆鐵皮屋頂)',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '大榮段',
#   '土地移轉面積': '28.73',
#   '代表地號都市土地使用分區': '其他-第四種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '150.39',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '7',
#   '代表建號建築完成日期': '770208',
#   '代表建號屋齡': '35',
#   '代表建號層次': '七層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '光榮街49號7樓之1',
#   '行政區': '鹽埕區',
#   '地段': '大榮段',
#   '代表地號': '1640000',
#   '代表建號': '535000',
#   '特殊交易態樣說明': '0304.其他增建'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '無',
#   '建物型態': '公寓(5樓含以下無電梯)',
#   '房地總價': '6,200,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120216',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '興橋段',
#   '土地移轉面積': '22.5',
#   '代表地號都市土地使用分區': '其他-第四種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '78.05',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '5',
#   '代表建號建築完成日期': '680811',
#   '代表建號屋齡': '44',
#   '代表建號層次': '一層;騎樓;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '田單街15號',
#   '行政區': '鹽埕區',
#   '地段': '興橋段',
#   '代表地號': '2130000',
#   '代表建號': '459000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '4',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '6,000,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111211',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '大勇段',
#   '土地移轉面積': '13.11',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '126.4',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '12',
#   '代表建號建築完成日期': '721230',
#   '代表建號屋齡': '39',
#   '代表建號層次': '九層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '必忠街171號9樓之4',
#   '行政區': '鹽埕區',
#   '地段': '大勇段',
#   '代表地號': '1620000',
#   '代表建號': '136000',
#   '特殊交易態樣說明': '0301.陽台外推'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '2',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '無',
#   '建物型態': '公寓(5樓含以下無電梯)',
#   '房地總價': '5,350,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1111228',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '府北段五小段',
#   '土地移轉面積': '11.21',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '59.18',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '5',
#   '代表建號建築完成日期': '701020',
#   '代表建號屋齡': '41',
#   '代表建號層次': '一層;騎樓;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '大有街33號',
#   '行政區': '鹽埕區',
#   '地段': '府北段五小段',
#   '代表地號': '2420000',
#   '代表建號': '975000',
#   '特殊交易態樣說明': '0304.其他增建'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '3',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '2',
#   '幾廳': '1',
#   '幾衛': '1',
#   '有無隔間': '有',
#   '建物型態': '公寓(5樓含以下無電梯)',
#   '房地總價': '5,200,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120103',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽北段',
#   '土地移轉面積': '14.6',
#   '代表地號都市土地使用分區': '其他-第四種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '53.51',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '5',
#   '代表建號建築完成日期': '691001',
#   '代表建號屋齡': '',
#   '代表建號層次': '一層;騎樓;夾層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '壽星街25巷17號',
#   '行政區': '鹽埕區',
#   '地段': '鹽北段',
#   '代表地號': '2860000',
#   '代表建號': '382000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '土地',
#   '土地數量': '2',
#   '建物數量': '0',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '無',
#   '建物型態': '',
#   '房地總價': '5,008,340',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120222',
#   '備註欄': '本件交易土地二筆',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '興橋段',
#   '土地移轉面積': '35.5',
#   '代表地號都市土地使用分區': '其他-第四種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '無建物主要建材',
#   '代表建號總層數': '',
#   '代表建號建築完成日期': '',
#   '代表建號屋齡': '',
#   '代表建號層次': '',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '興橋段 87-2 地號',
#   '行政區': '鹽埕區',
#   '地段': '興橋段',
#   '代表地號': '870002',
#   '代表建號': '',
#   '特殊交易態樣說明': '0701.政府機關標讓售'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '無',
#   '建物型態': '公寓(5樓含以下無電梯)',
#   '房地總價': '4,800,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120203',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鼓南段一小段',
#   '土地移轉面積': '18.45',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '96.53',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '5',
#   '代表建號建築完成日期': '770808',
#   '代表建號屋齡': '34',
#   '代表建號層次': '二層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '鼓山一路8號二樓',
#   '行政區': '鹽埕區',
#   '地段': '鼓南段一小段',
#   '代表地號': '990000',
#   '代表建號': '391000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '3',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '無',
#   '建物型態': '公寓(5樓含以下無電梯)',
#   '房地總價': '4,800,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120119',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽北段',
#   '土地移轉面積': '26.22',
#   '代表地號都市土地使用分區': '其他-第四種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '95.91',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '見其他登記事項',
#   '代表建號總層數': '5',
#   '代表建號建築完成日期': '691001',
#   '代表建號屋齡': '42',
#   '代表建號層次': '三層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '壽星街25巷13號3樓之1',
#   '行政區': '鹽埕區',
#   '地段': '鹽北段',
#   '代表地號': '2860000',
#   '代表建號': '368000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '2',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '3',
#   '幾廳': '1',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '4,750,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111226',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '興仁段',
#   '土地移轉面積': '7.35',
#   '代表地號都市土地使用分區': '其他-第五種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '91.13',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '12',
#   '代表建號建築完成日期': '721212',
#   '代表建號屋齡': '39',
#   '代表建號層次': '十二層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '七賢三路147號12樓之3',
#   '行政區': '鹽埕區',
#   '地段': '興仁段',
#   '代表地號': '5000000',
#   '代表建號': '21000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '4',
#   '幾廳': '1',
#   '幾衛': '2',
#   '有無隔間': '無',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '4,380,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120202',
#   '備註欄': '本標的物現況有滲漏水及壁癌等情形，買方同意自行維修並負擔修繕費用，賣方免除物之瑕疵擔保責任，惟若重大瑕疵除外(如：非自然身故、輻射屋、海砂屋...等)。',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '府北段五小段',
#   '土地移轉面積': '9.71',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '85.1',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '11',
#   '代表建號建築完成日期': '841017',
#   '代表建號屋齡': '27',
#   '代表建號層次': '三層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '大有街1號三樓',
#   '行政區': '鹽埕區',
#   '地段': '府北段五小段',
#   '代表地號': '1690000',
#   '代表建號': '1936000',
#   '特殊交易態樣說明': '0102.傢俱設備費'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '土地',
#   '土地數量': '1',
#   '建物數量': '0',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '無',
#   '建物型態': '',
#   '房地總價': '4,000,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120317',
#   '備註欄': '買賣價金包含地上未辦保存登記建物，該建物為透天厝型態，惟產權型態複雜，本次移轉有二個房屋稅籍，1層為權利範圍2分之1，3、5、6層權利範圍全部。',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽國段',
#   '土地移轉面積': '52',
#   '代表地號都市土地使用分區': '其他-第五種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '無建物主要建材',
#   '代表建號總層數': '',
#   '代表建號建築完成日期': '',
#   '代表建號屋齡': '',
#   '代表建號層次': '',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '鹽國段 430-0 地號',
#   '行政區': '鹽埕區',
#   '地段': '鹽國段',
#   '代表地號': '4300000',
#   '代表建號': '',
#   '特殊交易態樣說明': '0401.未登記建物'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '4',
#   '幾廳': '2',
#   '幾衛': '3',
#   '有無隔間': '有',
#   '建物型態': '透天厝',
#   '房地總價': '2,700,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1111208',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '大東段',
#   '土地移轉面積': '29',
#   '代表地號都市土地使用分區': '其他-第三種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '46.01',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '加強磚造',
#   '代表建號總層數': '2',
#   '代表建號建築完成日期': '590227',
#   '代表建號屋齡': '53',
#   '代表建號層次': '一層;二層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '瀨南街29之2號',
#   '行政區': '鹽埕區',
#   '地段': '大東段',
#   '代表地號': '6500000',
#   '代表建號': '428000',
#   '特殊交易態樣說明': '0304.其他增建'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '2',
#   '幾廳': '1',
#   '幾衛': '1',
#   '有無隔間': '無',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '2,550,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120211',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '府北段五小段',
#   '土地移轉面積': '5.16',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '59.4',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '12',
#   '代表建號建築完成日期': '690618',
#   '代表建號屋齡': '43',
#   '代表建號層次': '三層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '府北路36號3樓之4',
#   '行政區': '鹽埕區',
#   '地段': '府北段五小段',
#   '代表地號': '1460000',
#   '代表建號': '278000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '2',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '2',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '公寓(5樓含以下無電梯)',
#   '房地總價': '2,500,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1111206',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '興福段',
#   '土地移轉面積': '17.98',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '74.34',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '5',
#   '代表建號建築完成日期': '680221',
#   '代表建號屋齡': '44',
#   '代表建號層次': '二層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '五福四路325號二樓之3',
#   '行政區': '鹽埕區',
#   '地段': '興福段',
#   '代表地號': '2400000',
#   '代表建號': '220000',
#   '特殊交易態樣說明': '0304.其他增建'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '建物',
#   '土地數量': '0',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '2,300,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120103',
#   '備註欄': '土地所有權人為高雄市管理者高雄市政府經濟發展局',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '興仁段',
#   '土地移轉面積': '',
#   '代表地號都市土地使用分區': '-',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '133.69',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '810918',
#   '代表建號屋齡': '30',
#   '代表建號層次': '八層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '新樂街214號八樓之2',
#   '行政區': '鹽埕區',
#   '地段': '興仁段',
#   '代表地號': '',
#   '代表建號': '732000',
#   '特殊交易態樣說明': '0602.地上權房屋'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '2',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '4',
#   '幾廳': '2',
#   '幾衛': '4',
#   '有無隔間': '無',
#   '建物型態': '透天厝',
#   '房地總價': '2,265,600',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120213',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '大榮段',
#   '土地移轉面積': '60',
#   '代表地號都市土地使用分區': '其他-第四種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '168.42',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '4',
#   '代表建號建築完成日期': '810505',
#   '代表建號屋齡': '31',
#   '代表建號層次': '一層;二層;三層;四層;屋頂突出物;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '光榮街37巷5號',
#   '行政區': '鹽埕區',
#   '地段': '大榮段',
#   '代表地號': '3110000',
#   '代表建號': '580000',
#   '特殊交易態樣說明': '0201.親友、員工、共有人或其他特殊關係間之交易'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '1',
#   '幾廳': '1',
#   '幾衛': '1',
#   '有無隔間': '無',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '1,800,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120213',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '府北段五小段',
#   '土地移轉面積': '3.5',
#   '代表地號都市土地使用分區': '其他-第五種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '46.85',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '12',
#   '代表建號建築完成日期': '701124',
#   '代表建號屋齡': '41',
#   '代表建號層次': '五層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '府北路25號5樓之12',
#   '行政區': '鹽埕區',
#   '地段': '府北段五小段',
#   '代表地號': '2210000',
#   '代表建號': '1059000',
#   '特殊交易態樣說明': '0102.傢俱設備費'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '土地',
#   '土地數量': '1',
#   '建物數量': '0',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '有',
#   '建物型態': '',
#   '房地總價': '1,755,600',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120116',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽中段',
#   '土地移轉面積': '13.84',
#   '代表地號都市土地使用分區': '其他-第五種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '無建物主要建材',
#   '代表建號總層數': '',
#   '代表建號建築完成日期': '',
#   '代表建號屋齡': '',
#   '代表建號層次': '',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '鹽中段 28-0 地號',
#   '行政區': '鹽埕區',
#   '地段': '鹽中段',
#   '代表地號': '280000',
#   '代表建號': '',
#   '特殊交易態樣說明': '0401.未登記建物'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '1',
#   '幾廳': '1',
#   '幾衛': '1',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '1,650,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120115',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '府北段五小段',
#   '土地移轉面積': '4.04',
#   '代表地號都市土地使用分區': '其他-第五種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '47.91',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '12',
#   '代表建號建築完成日期': '701124',
#   '代表建號屋齡': '41',
#   '代表建號層次': '十層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '府北路25號10樓之28',
#   '行政區': '鹽埕區',
#   '地段': '府北段五小段',
#   '代表地號': '2210000',
#   '代表建號': '1151000',
#   '特殊交易態樣說明': '0102.傢俱設備費'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '1',
#   '幾廳': '1',
#   '幾衛': '1',
#   '有無隔間': '無',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '1,600,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120216',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '府北段五小段',
#   '土地移轉面積': '2.58',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '29.7',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '12',
#   '代表建號建築完成日期': '690618',
#   '代表建號屋齡': '43',
#   '代表建號層次': '九層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '府北路36號9樓之2',
#   '行政區': '鹽埕區',
#   '地段': '府北段五小段',
#   '代表地號': '1460000',
#   '代表建號': '430000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '無',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '1,520,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120216',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '府北段五小段',
#   '土地移轉面積': '2.78',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '32.1',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '12',
#   '代表建號建築完成日期': '690618',
#   '代表建號屋齡': '43',
#   '代表建號層次': '五層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '府北路36號5樓之11',
#   '行政區': '鹽埕區',
#   '地段': '府北段五小段',
#   '代表地號': '1460000',
#   '代表建號': '319000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '建物',
#   '土地數量': '0',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '1',
#   '幾廳': '0',
#   '幾衛': '1',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '1,450,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111216',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽壽段',
#   '土地移轉面積': '',
#   '代表地號都市土地使用分區': '-',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '38.84',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '16',
#   '代表建號建築完成日期': '750217',
#   '代表建號屋齡': '37',
#   '代表建號層次': '九層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '北斗街5號9樓之47',
#   '行政區': '鹽埕區',
#   '地段': '鹽壽段',
#   '代表地號': '',
#   '代表建號': '652000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '土地',
#   '土地數量': '1',
#   '建物數量': '0',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '無',
#   '建物型態': '',
#   '房地總價': '1,419,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120223',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽中段',
#   '土地移轉面積': '22',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '無建物主要建材',
#   '代表建號總層數': '',
#   '代表建號建築完成日期': '',
#   '代表建號屋齡': '',
#   '代表建號層次': '',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '鹽中段 323-0 地號',
#   '行政區': '鹽埕區',
#   '地段': '鹽中段',
#   '代表地號': '3230000',
#   '代表建號': '',
#   '特殊交易態樣說明': '0701.政府機關標讓售'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '1',
#   '幾廳': '0',
#   '幾衛': '1',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '1,400,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111220',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '府北段五小段',
#   '土地移轉面積': '2.42',
#   '代表地號都市土地使用分區': '其他-第五種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '35.06',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '12',
#   '代表建號建築完成日期': '701124',
#   '代表建號屋齡': '41',
#   '代表建號層次': '四層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '府北路25號4樓之13',
#   '行政區': '鹽埕區',
#   '地段': '府北段五小段',
#   '代表地號': '2210000',
#   '代表建號': '1248000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '1',
#   '幾廳': '1',
#   '幾衛': '1',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '1,200,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120104',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '府北段五小段',
#   '土地移轉面積': '2.42',
#   '代表地號都市土地使用分區': '其他-第五種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '30.98',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '12',
#   '代表建號建築完成日期': '701124',
#   '代表建號屋齡': '41',
#   '代表建號層次': '五層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '府北路25號5樓之27',
#   '行政區': '鹽埕區',
#   '地段': '府北段五小段',
#   '代表地號': '2210000',
#   '代表建號': '1074000',
#   '特殊交易態樣說明': '0201.親友、員工、共有人或其他特殊關係間之交易'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '1',
#   '幾廳': '0',
#   '幾衛': '1',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '1,150,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120218',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '府北段五小段',
#   '土地移轉面積': '2.98',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '32.1',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '12',
#   '代表建號建築完成日期': '690618',
#   '代表建號屋齡': '43',
#   '代表建號層次': '三層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '府北路36號3樓之7',
#   '行政區': '鹽埕區',
#   '地段': '府北段五小段',
#   '代表地號': '1460000',
#   '代表建號': '276000',
#   '特殊交易態樣說明': '0102.傢俱設備費'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '建物',
#   '土地數量': '0',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '1',
#   '幾廳': '1',
#   '幾衛': '1',
#   '有無隔間': '無',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '1,100,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1110911',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽壽段',
#   '土地移轉面積': '',
#   '代表地號都市土地使用分區': '-',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '34.8',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '16',
#   '代表建號建築完成日期': '750217',
#   '代表建號屋齡': '37',
#   '代表建號層次': '十一層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '七賢三路269號11樓之36',
#   '行政區': '鹽埕區',
#   '地段': '鹽壽段',
#   '代表地號': '',
#   '代表建號': '843000',
#   '特殊交易態樣說明': '0201.親友、員工、共有人或其他特殊關係間之交易0301.陽台外推'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '建物',
#   '土地數量': '0',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '1',
#   '幾廳': '0',
#   '幾衛': '1',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '960,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111206',
#   '備註欄': '本案土地向高雄市政府承租',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽壽段',
#   '土地移轉面積': '',
#   '代表地號都市土地使用分區': '-',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '33.83',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '16',
#   '代表建號建築完成日期': '750217',
#   '代表建號屋齡': '37',
#   '代表建號層次': '十一層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '七賢三路269號11樓之32',
#   '行政區': '鹽埕區',
#   '地段': '鹽壽段',
#   '代表地號': '',
#   '代表建號': '839000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '建物',
#   '土地數量': '0',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '無',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '920,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111208',
#   '備註欄': '土地向高雄市政府市場管理處承租',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽壽段',
#   '土地移轉面積': '',
#   '代表地號都市土地使用分區': '-',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '37.37',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '16',
#   '代表建號建築完成日期': '750217',
#   '代表建號屋齡': '37',
#   '代表建號層次': '十六層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '七賢三路269號16樓之22',
#   '行政區': '鹽埕區',
#   '地段': '鹽壽段',
#   '代表地號': '',
#   '代表建號': '882000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '2',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '2',
#   '幾廳': '1',
#   '幾衛': '2',
#   '有無隔間': '無',
#   '建物型態': '華廈(10層含以下有電梯)',
#   '房地總價': '916,008',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120220',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '興橋段',
#   '土地移轉面積': '14.97',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '108.63',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '7',
#   '代表建號建築完成日期': '701228',
#   '代表建號屋齡': '41',
#   '代表建號層次': '六層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '大仁路237之4號6樓之2',
#   '行政區': '鹽埕區',
#   '地段': '興橋段',
#   '代表地號': '2310000',
#   '代表建號': '106000',
#   '特殊交易態樣說明': '0201.親友、員工、共有人或其他特殊關係間之交易'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '建物',
#   '土地數量': '0',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '1',
#   '幾廳': '1',
#   '幾衛': '1',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '900,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120105',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽壽段',
#   '土地移轉面積': '',
#   '代表地號都市土地使用分區': '-',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '35.95',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '16',
#   '代表建號建築完成日期': '750217',
#   '代表建號屋齡': '37',
#   '代表建號層次': '七層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '北斗街5號7樓之38',
#   '行政區': '鹽埕區',
#   '地段': '鹽壽段',
#   '代表地號': '',
#   '代表建號': '537000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '1',
#   '幾廳': '1',
#   '幾衛': '1',
#   '有無隔間': '有',
#   '建物型態': '公寓(5樓含以下無電梯)',
#   '房地總價': '750,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120106',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '興仁段',
#   '土地移轉面積': '15.6',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '19.06',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '5',
#   '代表建號建築完成日期': '641022',
#   '代表建號屋齡': '47',
#   '代表建號層次': '五層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '大仁路193巷11號',
#   '行政區': '鹽埕區',
#   '地段': '興仁段',
#   '代表地號': '5550000',
#   '代表建號': '237000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '1',
#   '幾廳': '1',
#   '幾衛': '1',
#   '有無隔間': '有',
#   '建物型態': '華廈(10層含以下有電梯)',
#   '房地總價': '700,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111228',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '府北段五小段',
#   '土地移轉面積': '3.75',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '21.99',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '10',
#   '代表建號建築完成日期': '710531',
#   '代表建號屋齡': '41',
#   '代表建號層次': '十層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '富野路50號10樓之1',
#   '行政區': '鹽埕區',
#   '地段': '府北段五小段',
#   '代表地號': '2460000',
#   '代表建號': '1601000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '建物',
#   '土地數量': '0',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '1',
#   '幾廳': '0',
#   '幾衛': '1',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '700,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111224',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽壽段',
#   '土地移轉面積': '',
#   '代表地號都市土地使用分區': '-',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '37.39',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '16',
#   '代表建號建築完成日期': '750217',
#   '代表建號屋齡': '37',
#   '代表建號層次': '十一層;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '七賢三路269號11樓之48',
#   '行政區': '鹽埕區',
#   '地段': '鹽壽段',
#   '代表地號': '',
#   '代表建號': '855000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '土地',
#   '土地數量': '1',
#   '建物數量': '0',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '有',
#   '建物型態': '',
#   '房地總價': '636,270',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120201',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '大東段',
#   '土地移轉面積': '17.4',
#   '代表地號都市土地使用分區': '其他-第三種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '無建物主要建材',
#   '代表建號總層數': '',
#   '代表建號建築完成日期': '',
#   '代表建號屋齡': '',
#   '代表建號層次': '',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '大東段 671-0 地號',
#   '行政區': '鹽埕區',
#   '地段': '大東段',
#   '代表地號': '6710000',
#   '代表建號': '',
#   '特殊交易態樣說明': '0201.親友、員工、共有人或其他特殊關係間之交易0604.(包含)公共設施保留地(用地)'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '土地',
#   '土地數量': '1',
#   '建物數量': '0',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '無',
#   '建物型態': '',
#   '房地總價': '234,234',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120217',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '興仁段',
#   '土地移轉面積': '7',
#   '代表地號都市土地使用分區': '其他-道路用地',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '無建物主要建材',
#   '代表建號總層數': '',
#   '代表建號建築完成日期': '',
#   '代表建號屋齡': '',
#   '代表建號層次': '',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '興仁段 372-1 地號',
#   '行政區': '鹽埕區',
#   '地段': '興仁段',
#   '代表地號': '3720001',
#   '代表建號': '',
#   '特殊交易態樣說明': '0604.(包含)公共設施保留地(用地)'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '土地',
#   '土地數量': '1',
#   '建物數量': '0',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '有',
#   '建物型態': '',
#   '房地總價': '170,519',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1111028',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '興仁段',
#   '土地移轉面積': '7',
#   '代表地號都市土地使用分區': '其他-道路用地',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '無建物主要建材',
#   '代表建號總層數': '',
#   '代表建號建築完成日期': '',
#   '代表建號屋齡': '',
#   '代表建號層次': '',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '興仁段 372-1 地號',
#   '行政區': '鹽埕區',
#   '地段': '興仁段',
#   '代表地號': '3720001',
#   '代表建號': '',
#   '特殊交易態樣說明': '0604.(包含)公共設施保留地(用地)'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '土地',
#   '土地數量': '1',
#   '建物數量': '0',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '有',
#   '建物型態': '',
#   '房地總價': '2,628',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120119',
#   '備註欄': '',
#   '行政區代碼': '鹽埕區',
#   '代表段號': '鹽中段',
#   '土地移轉面積': '0.35',
#   '代表地號都市土地使用分區': '其他-道路用地',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '無建物主要建材',
#   '代表建號總層數': '',
#   '代表建號建築完成日期': '',
#   '代表建號屋齡': '',
#   '代表建號層次': '',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '鹽中段 28-1 地號',
#   '行政區': '鹽埕區',
#   '地段': '鹽中段',
#   '代表地號': '280001',
#   '代表建號': '',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '土地',
#   '土地數量': '1',
#   '建物數量': '0',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '有',
#   '建物型態': '',
#   '房地總價': '311,970,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1110627',
#   '備註欄': '',
#   '行政區代碼': '鼓山區',
#   '代表段號': '內惟段一小段',
#   '土地移轉面積': '1357',
#   '代表地號都市土地使用分區': '其他-第三種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '無建物主要建材',
#   '代表建號總層數': '',
#   '代表建號建築完成日期': '',
#   '代表建號屋齡': '',
#   '代表建號層次': '',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '內惟段一小段 1598-0 地號',
#   '行政區': '鼓山區',
#   '地段': '內惟段一小段',
#   '代表地號': '15980000',
#   '代表建號': '',
#   '特殊交易態樣說明': '0401.未登記建物'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '土地',
#   '土地數量': '2',
#   '建物數量': '0',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '有',
#   '建物型態': '',
#   '房地總價': '197,600,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1111029',
#   '備註欄': '',
#   '行政區代碼': '鼓山區',
#   '代表段號': '龍華段六小段',
#   '土地移轉面積': '544.5',
#   '代表地號都市土地使用分區': '其他-第五種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '無建物主要建材',
#   '代表建號總層數': '',
#   '代表建號建築完成日期': '',
#   '代表建號屋齡': '',
#   '代表建號層次': '',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '龍華段六小段 2186-4 地號',
#   '行政區': '鼓山區',
#   '地段': '龍華段六小段',
#   '代表地號': '21860004',
#   '代表建號': '',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '土地',
#   '土地數量': '3',
#   '建物數量': '0',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '有',
#   '建物型態': '',
#   '房地總價': '173,711,500',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1111202',
#   '備註欄': '',
#   '行政區代碼': '鼓山區',
#   '代表段號': '龍華段八小段',
#   '土地移轉面積': '436.71',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '無建物主要建材',
#   '代表建號總層數': '',
#   '代表建號建築完成日期': '',
#   '代表建號屋齡': '',
#   '代表建號層次': '',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '龍華段八小段 2316-8 地號',
#   '行政區': '鼓山區',
#   '地段': '龍華段八小段',
#   '代表地號': '23160008',
#   '代表建號': '',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '3',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '無',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '107,330,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '7,600,000',
#   '有無管理組織': '有',
#   '交易日期': '1120103',
#   '備註欄': '',
#   '行政區代碼': '鼓山區',
#   '代表段號': '龍中段',
#   '土地移轉面積': '33.51',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '608.36',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '見其他登記事項',
#   '代表建號總層數': '33',
#   '代表建號建築完成日期': '1070920',
#   '代表建號屋齡': '4',
#   '代表建號層次': '三十層;',
#   '車位總價格': '0',
#   '車位總持分面積': '86.56',
#   '代表地號或門牌': '富農路328號三十樓',
#   '行政區': '鼓山區',
#   '地段': '龍中段',
#   '代表地號': '1200000',
#   '代表建號': '7127000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '2',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '無',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '80,960,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '5,200,000',
#   '有無管理組織': '有',
#   '交易日期': '1120213',
#   '備註欄': '',
#   '行政區代碼': '鼓山區',
#   '代表段號': '龍中段',
#   '土地移轉面積': '29.06',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '493.56',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '見其他登記事項',
#   '代表建號總層數': '36',
#   '代表建號建築完成日期': '1041104',
#   '代表建號屋齡': '7',
#   '代表建號層次': '九層;',
#   '車位總價格': '0',
#   '車位總持分面積': '38.38',
#   '代表地號或門牌': '神農路87號九樓',
#   '行政區': '鼓山區',
#   '地段': '龍中段',
#   '代表地號': '270000',
#   '代表建號': '6915000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '土地',
#   '土地數量': '1',
#   '建物數量': '0',
#   '車位數量': '',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '有',
#   '建物型態': '',
#   '房地總價': '43,500,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1111219',
#   '備註欄': '',
#   '行政區代碼': '鼓山區',
#   '代表段號': '青海段',
#   '土地移轉面積': '218.09',
#   '代表地號都市土地使用分區': '其他-特定第五種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '無建物主要建材',
#   '代表建號總層數': '',
#   '代表建號建築完成日期': '',
#   '代表建號屋齡': '',
#   '代表建號層次': '',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '青海段 25-0 地號',
#   '行政區': '鼓山區',
#   '地段': '青海段',
#   '代表地號': '250000',
#   '代表建號': '',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '4',
#   '幾廳': '0',
#   '幾衛': '3',
#   '有無隔間': '有',
#   '建物型態': '透天厝',
#   '房地總價': '43,000,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1111122',
#   '備註欄': '',
#   '行政區代碼': '鼓山區',
#   '代表段號': '內惟段六小段',
#   '土地移轉面積': '140',
#   '代表地號都市土地使用分區': '其他-第三種特定商業專用區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '308.88',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '加強磚造',
#   '代表建號總層數': '3',
#   '代表建號建築完成日期': '630501',
#   '代表建號屋齡': '49',
#   '代表建號層次': '一層;二層;三層;騎樓;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '九如四路692號',
#   '行政區': '鼓山區',
#   '地段': '內惟段六小段',
#   '代表地號': '3280000',
#   '代表建號': '78000',
#   '特殊交易態樣說明': '0102.傢俱設備費0302.頂樓加蓋0304.其他增建'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '2',
#   '幾房': '5',
#   '幾廳': '2',
#   '幾衛': '3',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '41,000,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111210',
#   '備註欄': '',
#   '行政區代碼': '鼓山區',
#   '代表段號': '龍中段',
#   '土地移轉面積': '26.03',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '496.47',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼骨鋼筋混凝土造',
#   '代表建號總層數': '36',
#   '代表建號建築完成日期': '1030626',
#   '代表建號屋齡': '8',
#   '代表建號層次': '二十七層;',
#   '車位總價格': '0',
#   '車位總持分面積': '52.55',
#   '代表地號或門牌': '龍德路295號二十七樓',
#   '行政區': '鼓山區',
#   '地段': '龍中段',
#   '代表地號': '960000',
#   '代表建號': '6468000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '2',
#   '幾房': '',
#   '幾廳': '',
#   '幾衛': '',
#   '有無隔間': '無',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '39,980,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '2,700,000',
#   '有無管理組織': '有',
#   '交易日期': '1111015',
#   '備註欄': '',
#   '行政區代碼': '鼓山區',
#   '代表段號': '龍中段',
#   '土地移轉面積': '25.23',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '438.98',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '見其他登記事項',
#   '代表建號總層數': '38',
#   '代表建號建築完成日期': '1040915',
#   '代表建號屋齡': '7',
#   '代表建號層次': '三十七層;',
#   '車位總價格': '0',
#   '車位總持分面積': '39.52',
#   '代表地號或門牌': '龍勝路291號三十七樓',
#   '行政區': '鼓山區',
#   '地段': '龍中段',
#   '代表地號': '1330000',
#   '代表建號': '6744000',
#   '特殊交易態樣說明': '0505.毛胚屋'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '4',
#   '幾廳': '2',
#   '幾衛': '5',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '39,900,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '2,600,000',
#   '有無管理組織': '有',
#   '交易日期': '1111027',
#   '備註欄': '',
# ...
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111209',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '藍田中段',
#   '土地移轉面積': '24.87',
#   '代表地號都市土地使用分區': '其他-第三種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '135.65',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '見其他登記事項',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '1051115',
#   '代表建號屋齡': '6',
#   '代表建號層次': '六層;',
#   '車位總價格': '0',
#   '車位總持分面積': '24.7',
#   '代表地號或門牌': '大學五十街72號六樓',
#   '行政區': '楠梓區',
#   '地段': '藍田中段',
#   '代表地號': '3340000',
#   '代表建號': '1728000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '10,680,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120202',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '加昌段二小段',
#   '土地移轉面積': '12.02',
#   '代表地號都市土地使用分區': '其他-第四種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '163.46',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '1020531',
#   '代表建號屋齡': '10',
#   '代表建號層次': '六層;',
#   '車位總價格': '0',
#   '車位總持分面積': '24.79',
#   '代表地號或門牌': '秀群路499巷7弄17號六樓',
#   '行政區': '楠梓區',
#   '地段': '加昌段二小段',
#   '代表地號': '19400000',
#   '代表建號': '5707000',
#   '特殊交易態樣說明': '0101.裝潢費0102.傢俱設備費'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '10,660,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '1,500,000',
#   '有無管理組織': '有',
#   '交易日期': '1120213',
#   '備註欄': '車位編號:22',
#   '行政區代碼': '楠梓區',
#   '代表段號': '楠梓段三小段',
#   '土地移轉面積': '13.41',
#   '代表地號都市土地使用分區': '其他-第三種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '160.09',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '1011109',
#   '代表建號屋齡': '10',
#   '代表建號層次': '十四層;',
#   '車位總價格': '1,500,000',
#   '車位總持分面積': '28.79',
#   '代表地號或門牌': '青埔街78號十四樓',
#   '行政區': '楠梓區',
#   '地段': '楠梓段三小段',
#   '代表地號': '1220000',
#   '代表建號': '1843000',
#   '特殊交易態樣說明': '0301.陽台外推'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '2',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '10,600,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111119',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '藍田中段',
#   '土地移轉面積': '22.45',
#   '代表地號都市土地使用分區': '其他-第三種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '127.66',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '見其他登記事項',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '1051115',
#   '代表建號屋齡': '6',
#   '代表建號層次': '十四層;',
#   '車位總價格': '0',
#   '車位總持分面積': '24.69',
#   '代表地號或門牌': '大學五十街52號十四樓',
#   '行政區': '楠梓區',
#   '地段': '藍田中段',
#   '代表地號': '3340000',
#   '代表建號': '1706000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '10,600,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120201',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '藍田中段',
#   '土地移轉面積': '24.87',
#   '代表地號都市土地使用分區': '其他-第三種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '135.65',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '見其他登記事項',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '1051115',
#   '代表建號屋齡': '6',
#   '代表建號層次': '五層;',
#   '車位總價格': '0',
#   '車位總持分面積': '24.69',
#   '代表地號或門牌': '大學五十街72號五樓',
#   '行政區': '楠梓區',
#   '地段': '藍田中段',
#   '代表地號': '3340000',
#   '代表建號': '1727000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '10,500,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111223',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '藍田西段',
#   '土地移轉面積': '20.94',
#   '代表地號都市土地使用分區': '其他-第四種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '153.45',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '見其他登記事項',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '1070213',
#   '代表建號屋齡': '5',
#   '代表建號層次': '九層;',
#   '車位總價格': '0',
#   '車位總持分面積': '13.53',
#   '代表地號或門牌': '大學二十五路268號九樓',
#   '行政區': '楠梓區',
#   '地段': '藍田西段',
#   '代表地號': '580000',
#   '代表建號': '1837000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '2',
#   '幾廳': '1',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '10,500,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '800,000',
#   '有無管理組織': '有',
#   '交易日期': '1111010',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '楠都段三小段',
#   '土地移轉面積': '12.23',
#   '代表地號都市土地使用分區': '其他-第三種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '118.23',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '見其他登記事項',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '1110708',
#   '代表建號屋齡': '0',
#   '代表建號層次': '十二層;',
#   '車位總價格': '800,000',
#   '車位總持分面積': '8.59',
#   '代表地號或門牌': '朝明路20巷23號十二樓',
#   '行政區': '楠梓區',
#   '地段': '楠都段三小段',
#   '代表地號': '10500000',
#   '代表建號': '1895000',
#   '特殊交易態樣說明': '0201.親友、員工、共有人或其他特殊關係間之交易'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '4',
#   '幾廳': '2',
#   '幾衛': '3',
#   '有無隔間': '有',
#   '建物型態': '透天厝',
#   '房地總價': '10,500,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120108',
#   '備註欄': '頂樓增建',
#   '行政區代碼': '楠梓區',
#   '代表段號': '右昌段一小段',
#   '土地移轉面積': '56',
#   '代表地號都市土地使用分區': '其他-第三種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '127.03',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '3',
#   '代表建號建築完成日期': '771012',
#   '代表建號屋齡': '34',
#   '代表建號層次': '一層;二層;三層;屋頂突出物;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '通昌街211號',
#   '行政區': '楠梓區',
#   '地段': '右昌段一小段',
#   '代表地號': '5560019',
#   '代表建號': '421000',
#   '特殊交易態樣說明': '0102.傢俱設備費'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '10,350,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '1,550,000',
#   '有無管理組織': '有',
#   '交易日期': '1090906',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '芎蕉段',
#   '土地移轉面積': '20.2',
#   '代表地號都市土地使用分區': '其他-商業區(特)',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '182.77',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '見其他登記事項',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '1120117',
#   '代表建號屋齡': '0',
#   '代表建號層次': '十五層;',
#   '車位總價格': '1,550,000',
#   '車位總持分面積': '20.12',
#   '代表地號或門牌': '創新路879號十五樓',
#   '行政區': '楠梓區',
#   '地段': '芎蕉段',
#   '代表地號': '130000',
#   '代表建號': '2469000',
#   '特殊交易態樣說明': '0901.預售屋、或土地及建物分件登記案件'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '10,300,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111217',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '清豐段',
#   '土地移轉面積': '26.93',
#   '代表地號都市土地使用分區': '其他-第三種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '158.41',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '見其他登記事項',
#   '代表建號總層數': '23',
#   '代表建號建築完成日期': '1040216',
#   '代表建號屋齡': '8',
#   '代表建號層次': '十五層;',
#   '車位總價格': '0',
#   '車位總持分面積': '16.03',
#   '代表地號或門牌': '土庫二路26號十五樓',
#   '行政區': '楠梓區',
#   '地段': '清豐段',
#   '代表地號': '1940001',
#   '代表建號': '5939000',
#   '特殊交易態樣說明': '0201.親友、員工、共有人或其他特殊關係間之交易'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '10,150,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120303',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '和平東段',
#   '土地移轉面積': '22.5',
#   '代表地號都市土地使用分區': '其他-第三種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '147',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '見其他登記事項',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '1090108',
#   '代表建號屋齡': '3',
#   '代表建號層次': '二層;',
#   '車位總價格': '0',
#   '車位總持分面積': '22',
#   '代表地號或門牌': '金富街111號二樓之1',
#   '行政區': '楠梓區',
#   '地段': '和平東段',
#   '代表地號': '420000',
#   '代表建號': '288000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '2',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '10,000,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120112',
#   '備註欄': '2樓後方增建鐵窗，買賣總價包含土地款450萬及建物含車位款550萬元。',
#   '行政區代碼': '楠梓區',
#   '代表段號': '和平段五小段',
#   '土地移轉面積': '10.15',
#   '代表地號都市土地使用分區': '其他-第五種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '163.38',
#   '代表建號主要用途': '住商用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '23',
#   '代表建號建築完成日期': '851028',
#   '代表建號屋齡': '26',
#   '代表建號層次': '一層;二層;騎樓;',
#   '車位總價格': '0',
#   '車位總持分面積': '0',
#   '代表地號或門牌': '德民路428號',
#   '行政區': '楠梓區',
#   '地段': '和平段五小段',
#   '代表地號': '2630000',
#   '代表建號': '3320000',
#   '特殊交易態樣說明': '0102.傢俱設備費0304.其他增建'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '6',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '6',
#   '幾廳': '1',
#   '幾衛': '4',
#   '有無隔間': '有',
#   '建物型態': '透天厝',
#   '房地總價': '10,000,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1120208',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '楠梓段二小段',
#   '土地移轉面積': '115.13',
#   '代表地號都市土地使用分區': '其他-第三種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '213.28',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '4',
#   '代表建號建築完成日期': '870909',
#   '代表建號屋齡': '24',
#   '代表建號層次': '一層;二層;三層;四層;屋頂突出物;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '高楠公路1870巷29弄27號',
#   '行政區': '楠梓區',
#   '地段': '楠梓段二小段',
#   '代表地號': '1190030',
#   '代表建號': '728000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '2',
#   '幾廳': '2',
#   '幾衛': '1',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '9,950,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '1,800,000',
#   '有無管理組織': '有',
#   '交易日期': '1111016',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '藍田西段',
#   '土地移轉面積': '11.2',
#   '代表地號都市土地使用分區': '其他-第四種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '106.67',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '1110429',
#   '代表建號屋齡': '0',
#   '代表建號層次': '十五層;',
#   '車位總價格': '1,800,000',
#   '車位總持分面積': '24.95',
#   '代表地號或門牌': '大學十七街7號十五樓',
#   '行政區': '楠梓區',
#   '地段': '藍田西段',
#   '代表地號': '3240000',
#   '代表建號': '2823000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '2',
#   '幾廳': '1',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '9,930,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '800,000',
#   '有無管理組織': '有',
#   '交易日期': '1111130',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '楠都段三小段',
#   '土地移轉面積': '12.23',
#   '代表地號都市土地使用分區': '其他-第三種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '118.23',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '見其他登記事項',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '1110708',
#   '代表建號屋齡': '0',
#   '代表建號層次': '七層;',
#   '車位總價格': '800,000',
#   '車位總持分面積': '8.59',
#   '代表地號或門牌': '朝明路20巷25號七樓',
#   '行政區': '楠梓區',
#   '地段': '楠都段三小段',
#   '代表地號': '10500000',
#   '代表建號': '1904000',
#   '特殊交易態樣說明': '0201.親友、員工、共有人或其他特殊關係間之交易'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '9,800,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111125',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '加昌段',
#   '土地移轉面積': '15.33',
#   '代表地號都市土地使用分區': '其他-第五種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '132.21',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '941130',
#   '代表建號屋齡': '17',
#   '代表建號層次': '十四層;',
#   '車位總價格': '0',
#   '車位總持分面積': '20.01',
#   '代表地號或門牌': '加宏路117巷13號十四樓',
#   '行政區': '楠梓區',
#   '地段': '加昌段',
#   '代表地號': '12550000',
#   '代表建號': '5459000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)',
#   '土地數量': '3',
#   '建物數量': '1',
#   '車位數量': '',
#   '幾房': '2',
#   '幾廳': '1',
#   '幾衛': '1',
#   '有無隔間': '有',
#   '建物型態': '公寓(5樓含以下無電梯)',
#   '房地總價': '9,750,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '無',
#   '交易日期': '1111210',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '加昌段',
#   '土地移轉面積': '35.25',
#   '代表地號都市土地使用分區': '其他-第四種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '82.94',
#   '代表建號主要用途': '無建物主要用途資料',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '4',
#   '代表建號建築完成日期': '680908',
#   '代表建號屋齡': '43',
#   '代表建號層次': '一層;騎樓;',
#   '車位總價格': '',
#   '車位總持分面積': '',
#   '代表地號或門牌': '樂群路229號',
#   '行政區': '楠梓區',
#   '地段': '加昌段',
#   '代表地號': '7050000',
#   '代表建號': '1785000',
#   '特殊交易態樣說明': '0304.其他增建'},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '9,680,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1120203',
#   '備註欄': '另附一格機車車位',
#   '行政區代碼': '楠梓區',
#   '代表段號': '德昌段',
#   '土地移轉面積': '17.82',
#   '代表地號都市土地使用分區': '其他-第五種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '146.15',
#   '代表建號主要用途': '住家用',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '970917',
#   '代表建號屋齡': '14',
#   '代表建號層次': '十四層;',
#   '車位總價格': '0',
#   '車位總持分面積': '23.23',
#   '代表地號或門牌': '榮新街25號十四樓',
#   '行政區': '楠梓區',
#   '地段': '德昌段',
#   '代表地號': '1580000',
#   '代表建號': '1911000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '3',
#   '幾廳': '1',
#   '幾衛': '2',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '9,650,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '',
#   '有無管理組織': '有',
#   '交易日期': '1111205',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '清豐段',
#   '土地移轉面積': '16.04',
#   '代表地號都市土地使用分區': '其他-第二種特定商業專用區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '126.53',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '見其他登記事項',
#   '代表建號總層數': '14',
#   '代表建號建築完成日期': '1060516',
#   '代表建號屋齡': '6',
#   '代表建號層次': '八層;',
#   '車位總價格': '0',
#   '車位總持分面積': '15.34',
#   '代表地號或門牌': '清豐路221號八樓',
#   '行政區': '楠梓區',
#   '地段': '清豐段',
#   '代表地號': '2060000',
#   '代表建號': '6439000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '3',
#   '幾廳': '2',
#   '幾衛': '2',
#   '有無隔間': '無',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '9,620,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '1,000,000',
#   '有無管理組織': '有',
#   '交易日期': '1111231',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '援中段一小段',
#   '土地移轉面積': '11.64',
#   '代表地號都市土地使用分區': '其他-第三種商業區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '127.43',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '見其他登記事項',
#   '代表建號總層數': '18',
#   '代表建號建築完成日期': '1110923',
#   '代表建號屋齡': '0',
#   '代表建號層次': '四層;',
#   '車位總價格': '1,000,000',
#   '車位總持分面積': '12.22',
#   '代表地號或門牌': '大學二十七街162號四樓',
#   '行政區': '楠梓區',
#   '地段': '援中段一小段',
#   '代表地號': '3110000',
#   '代表建號': '2490000',
#   '特殊交易態樣說明': ''},
#  {'\ufeff申報種類': '買賣',
#   '交易標的種類': '房地(土地+建物)+車位',
#   '土地數量': '1',
#   '建物數量': '1',
#   '車位數量': '1',
#   '幾房': '2',
#   '幾廳': '2',
#   '幾衛': '1',
#   '有無隔間': '有',
#   '建物型態': '住宅大樓(11層含以上有電梯)',
#   '房地總價': '9,500,000',
#   '土地總價': '',
#   '建物總價': '',
#   '車位總價': '1,900,000',
#   '有無管理組織': '有',
#   '交易日期': '1111121',
#   '備註欄': '',
#   '行政區代碼': '楠梓區',
#   '代表段號': '藍田西段',
#   '土地移轉面積': '11.2',
#   '代表地號都市土地使用分區': '其他-第四種住宅區',
#   '代表地號非都市土地使用分區': '無使用分區資料',
#   '代表地號非都市土地使用地': '無土地編定使用地類別資料',
#   '建物移轉面積': '106.67',
#   '代表建號主要用途': '見其他登記事項',
#   '代表建號主要建材': '鋼筋混凝土造',
#   '代表建號總層數': '15',
#   '代表建號建築完成日期': '1110429',
#   '代表建號屋齡': '1',
#   '代表建號層次': '四層;',
#   '車位總價格': '1,900,000',
#   '車位總持分面積': '24.95',
#   '代表地號或門牌': '大學十七街7號四樓',
#   '行政區': '楠梓區',
#   '地段': '藍田西段',
#   '代表地號': '3240000',
#   '代表建號': '2812000',
#   '特殊交易態樣說明': ''},
#  ...]
