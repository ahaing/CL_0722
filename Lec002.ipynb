# %%
import requests
# 用 get

url='https://data.kcg.gov.tw/dataset/112realpricedata20'
# Response (實體) 裡面有 attribute 也有 property； 還有有帶括號的，是一個 method() 
response = requests.get(url)

# %%
# 用response 去遙控 Response， response裡面有個 response.content 的屬性(attribute)
response.content

# 找一個 property 叫 text
# Out:
# b'<!DOCTYPE html>\n<!--[if IE 7]> <html lang="zh_TW" class="ie ie7"> <![endif]-->\n<!--[if IE 8]> <html lang="zh_TW" class="ie ie8"> <![endif]-->\n<!--[if IE 9]> <html lang="zh_TW" class="ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="zh_TW"> <!--<![endif]-->\n  <head>\n    <!--[if lte ie 8]><script type="text/javascript" src="/fanstatic/vendor/:version:2022-09-23T09:55:14.21/html5.min.js"></script><![endif]-->\n<link rel="stylesheet" type="text/css" href="/fanstatic/vendor/:version:2022-09-23T09:55:14.21/select2/select2.css" />\n<link rel="stylesheet" type="text/css" href="/fanstatic/css/:version:2016-05-18T18:42:50/main.min.css" />\n<link rel="stylesheet" type="text/css" href="/fanstatic/vendor/:version:2022-09-23T09:55:14.21/font-awesome/css/font-awesome.min.css" />\n<!--[if ie 7]><link rel="stylesheet" type="text/css" href="/fanstatic/vendor/:version:2022-09-23T09:55:14.21/font-awesome/css/font-awesome-ie7.min.css" /><![endif]-->\n<link rel="stylesheet" type="text/css" href="/fanstatic/pages/:version:2016-05-23T15:56:49/:bundle:css/bootstrap.css;css/medium-editor.css" />\n\n    \n\n\n  <meta charset="utf-8" />\n      <meta name="generator" content="ckan 2.5.2" />\n      <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="google-signin-scope" content="profile email">\n    <meta name="google-signin-client_id" content="1060674162363-mvskkcmkkuh2b5f42svorksg4ncr10o3.apps.googleusercontent.com">\n    <meta name="google-signin-hosted_domain" content="">\n\n    <title>\xe9\xab\x98\xe9\x9b\x84\xe5\xb8\x82112\xe5\xb9\xb4\xe4\xb8\x8d\xe5\x8b\x95\xe7\x94\xa2\xe8\xb2\xb7\xe8\xb3\xa3\xe5\xaf\xa6\xe5\x83\xb9\xe7\x99\xbb\xe9\x8c\x84\xe8\xb3\x87\xe6\x96\x99\xe4\xb8\x8b\xe8\xbc\x89 - \xe8\xb3\x87\xe6\x96\x99\xe9\x9b\x86 - \xe9\xab\x98\xe9\x9b\x84\xe5\xb8\x82\xe6\x94\xbf\xe5\xba\x9c\xe8\xb3\x87\xe6\x96\x99\xe9\x96\x8b\xe6\x94\xbe</title>\n\n    \n    \n    <link rel="shortcut icon" href="/base/images/ckan.ico" />\n    \n\n    <!--[if IE]>\n    <script src="/classList.min.js"></script>\n    <![endif]-->\n\n    \n    \n    \n    \n\n    <link rel="stylesheet" type="text/css" href="/base/css/gbutton.css">\n    <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css">\n    \n      \n    \n\n\n    \n      \n      \n    \n  \n  <meta property="og:title" content="\xe9\xab\x98\xe9\x9b\x84\xe5\xb8\x82112\xe5\xb9\xb4\xe4\xb8\x8d\xe5\x8b\x95\xe7\x94\xa2\xe8\xb2\xb7\xe8\xb3\xa3\xe5\xaf\xa6\xe5\x83\xb9\xe7\x99\xbb\xe9\x8c\x84\xe8\xb3\x87\xe6\x96\x99\xe4\xb8\x8b\xe8\xbc\x89 - \xe9\xab\x98\xe9\x9b\x84\xe5\xb8\x82\xe6\x94\xbf\xe5\xba\x9c\xe8\xb3\x87\xe6\x96\x99\xe9\x96\x8b\xe6\x94\xbe">\n  <meta property="og:description" content="\xe6\x8f\x90\xe4\xbe\x9b\xe9\xab\x98\xe9\x9b\x84\xe5\xb8\x82112\xe5\xb9\xb4\xe5\x90\x84\xe5\xad\xa3\xe5\xaf\xa6\xe5\x83\xb9\xe7\x99\xbb\xe9\x8c\x84\xe8\xb2\xb7\xe8\xb3\xa3\xe6\x88\x90\xe4\xba\xa4\xe6\xa1\x88\xe4\xbb\xb6\xe8\xb3\x87\xe8\xa8\x8a">\n<style>\n        body {\r\n\tfont: 15px \'Microsoft JhengHei\';\r\n\tbackground-color: #a3a3a3;\r\n}\r\n\r\na {\r\n    color: #2c7f6f;\r\n}\r\n\r\n.homepage.layout-1 {\r\n\tbackground-color: #f0f0f1;\r\n}\r\n\r\n.account-masthead {\r\n    background: #221E1F;\r\n}\r\n\r\n.header-image {\r\n\tpadding-top: 0.4em;\r\n}\r\n\r\n.account-masthead .account ul li a {\r\n\tcolor: #fff;\r\n}\r\n\r\n.account-masthead .account ul li a:hover {\r\n    color: #221e1f;\r\n    background-color: #fff;\r\n}\r\n\r\n.masthead {\r\n\tbackground-color: #fff; \r\n}\r\n\r\n.masthead .nav>li>a, .masthead .nav>li>a:focus, .masthead .nav>li>a:hover, .masthead .nav>.active>a, .masthead .nav>.active>a:hover, .masthead .nav>.active>a:focus {\r\n\tcolor: #A81B04;\r\n}\r\n\r\n.masthead .navigation .nav-pills li a:hover, .masthead .navigation .nav-pills li.active a {\r\n    background-color: transparent;\r\n    border-radius: 0;\r\n    border-bottom: 3px solid #A81B04;\r\n}\r\n\r\n.masthead input[type="text"] {\r\n    border-color: #666;\r\n}\ ...
